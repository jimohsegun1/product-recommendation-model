# %% [markdown]
# dataset- 44k images(kaggle) related to the fashion products
# we are using a pre-trained CNN model which is already trained on huge data set, we just import the model and config it according to our requirement.
# we are using ResNet-50 CNN model this model got trained on image net data set with more than millions of images
# The resnet 50 can classify images into thousand different objects, and it can extract the features from the image(i.e objects inside the image), it can extract 2400 objects from a single image.
#
# so, in our project we similarly extract the features from each image in the dataset, and then identify the similar features images based on the input image features.
# the features will be feeded to nearest neighbors algorithm, based upon the features of 44k images distance will be calculated, to identify the similar product images we will be identifying the nearest image features based on the eidan distance, this is how the fashion recommendation model is going to built on CNN model and deploy as a web application

# %%
#Importing Libraries

# %% [markdown]
# numpy -
# pickle - to save the models

# %%
import numpy as np
import pickle as pkl
import tensorflow as tf
from tensorflow.keras.applications.resnet50 import ResNet50,preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.layers import GlobalMaxPool2D

from sklearn.neighbors import NearestNeighbors
import os
from numpy.linalg import norm

# %% [markdown]
# #Extract Filenames from Folder
# filenames - array of all the image file name(entire location)
# ex. 'images\\10005.jpg'

# %%
filenames = []
for file in os.listdir('images'):
    filenames.append(os.path.join('images',file))

# %%
len(filenames)
filenames[5]
# Out:
# 'images\\11157.jpg'

# %% [markdown]
# #Importing ResNet50 Model and Cofiguration.
# weights = imagenet - The ResNet-50 is trained on imagenet data set
# include_top=False - excluding the top layer of ResNet50 , we will be replacing it with our own layer.
# input_shape=(224,224,3) - height, width of the image & 3 implies the color(RGB)
# the model accepts numpy array
#
# model.trainable = False - beacuse we are simply using the already trained model

# %%
model = ResNet50(weights='imagenet', include_top=False, input_shape=(224,224,3))
model.trainable = False
# the top layer - to accept 2d array
model = tf.keras.models.Sequential([model,
                                   GlobalMaxPool2D()
                                   ])
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ resnet50 (Functional)           │ (None, 7, 7, 2048)     │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_max_pooling2d_1          │ (None, 2048)           │             0 │
# │ (GlobalMaxPooling2D)            │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,587,712 (89.98 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 23,587,712 (89.98 MB)

# %% [markdown]
# #Extracting Fetaures from Image

# %%
img = image.load_img('8852.jpg', target_size=(224,224))
img_array = image.img_to_array(img) #converting the img into array
img_expand_dim = np.expand_dims(img_array, axis=0) #3d array to 4d array
img_preprocess = preprocess_input(img_expand_dim) #RGB to BRG 
result = model.predict(img_preprocess).flatten() # feature extraction
norm_result = result/norm(result)
norm_result
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# array([0.01068562, 0.02334656, 0.01147304, ..., 0.00236327, 0.01932811,
#        0.02570377], dtype=float32)

# %%
def extract_features_from_images(image_path, model):
    img = image.load_img(image_path, target_size=(224,224))
    img_array = image.img_to_array(img)
    img_expand_dim = np.expand_dims(img_array, axis=0)
    img_preprocess = preprocess_input(img_expand_dim)
    result = model.predict(img_preprocess).flatten()
    norm_result = result/norm(result)
    return norm_result

# %%
extract_features_from_images(filenames[0], model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# array([0.        , 0.02987779, 0.01090513, ..., 0.        , 0.00727855,
#        0.01605097], dtype=float32)

# %%
image_features = []
for file in filenames:
    image_features.append(extract_features_from_images(file, model))
image_features
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 952ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 583ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 446ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 555ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 506ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 531ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 791ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 533ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 761ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 449ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# [array([0.        , 0.02987779, 0.01090513, ..., 0.        , 0.00727855,
#         0.01605097], dtype=float32),
#  array([0.        , 0.02379632, 0.00061573, ..., 0.        , 0.01353859,
#         0.01609405], dtype=float32),
#  array([0.00302331, 0.01935214, 0.00037897, ..., 0.        , 0.03349728,
#         0.01362018], dtype=float32),
#  array([0.        , 0.00651296, 0.01086532, ..., 0.        , 0.00190819,
#         0.00254074], dtype=float32),
#  array([0.00890286, 0.02897978, 0.00926227, ..., 0.00298901, 0.02362044,
#         0.0074232 ], dtype=float32),
#  array([0.        , 0.02205114, 0.        , ..., 0.        , 0.0106852 ,
#         0.01738822], dtype=float32),
#  array([0.00371639, 0.03027755, 0.0040463 , ..., 0.        , 0.        ,
#         0.02305364], dtype=float32),
#  array([0.0055463 , 0.03801173, 0.        , ..., 0.0022276 , 0.03026518,
#         0.03849157], dtype=float32),
#  array([0.00659018, 0.03179044, 0.00093824, ..., 0.00506388, 0.03771403,
#         0.03701031], dtype=float32),
#  array([0.01253564, 0.03090681, 0.00058704, ..., 0.        , 0.03090793,
#         0.03387589], dtype=float32),
#  array([0.0011134 , 0.05789919, 0.00909688, ..., 0.00704886, 0.05331863,
#         0.0490729 ], dtype=float32),
#  array([0.00926223, 0.02946928, 0.        , ..., 0.00575591, 0.06552162,
#         0.0386513 ], dtype=float32),
#  array([0.01123432, 0.00690578, 0.        , ..., 0.00763577, 0.013264  ,
#         0.0320836 ], dtype=float32),
#  array([0.00149153, 0.02122055, 0.00094445, ..., 0.        , 0.01279463,
#         0.06087222], dtype=float32),
#  array([0.0136829 , 0.03862863, 0.00583241, ..., 0.00628756, 0.03737215,
#         0.01224892], dtype=float32),
#  array([0.00553193, 0.03033968, 0.01680379, ..., 0.01540983, 0.05120439,
#         0.08066896], dtype=float32),
#  array([0.00385517, 0.03514554, 0.        , ..., 0.00866229, 0.0479138 ,
#         0.0190653 ], dtype=float32),
#  array([0.00116581, 0.0467301 , 0.        , ..., 0.01688572, 0.03667535,
#         0.03483555], dtype=float32),
#  array([0.00983658, 0.03630982, 0.00659387, ..., 0.        , 0.02732133,
#         0.01045337], dtype=float32),
#  array([0.00853799, 0.05613375, 0.01175305, ..., 0.03977423, 0.02156919,
#         0.05264048], dtype=float32),
#  array([0.00262706, 0.02783274, 0.01240434, ..., 0.00990594, 0.03394953,
#         0.02671245], dtype=float32),
#  array([0.01202233, 0.02453365, 0.00395281, ..., 0.01123151, 0.04518665,
#         0.09376523], dtype=float32),
#  array([0.00320872, 0.00974973, 0.01120769, ..., 0.00136141, 0.04163035,
#         0.07959642], dtype=float32),
#  array([0.00827908, 0.0154733 , 0.00634683, ..., 0.01109859, 0.04839697,
#         0.08372318], dtype=float32),
#  array([0.00865644, 0.00298593, 0.        , ..., 0.00582581, 0.03985427,
#         0.0372025 ], dtype=float32),
#  array([0.00484349, 0.02390221, 0.        , ..., 0.01917904, 0.02875557,
#         0.0637216 ], dtype=float32),
#  array([0.00860829, 0.02840863, 0.        , ..., 0.00886424, 0.01718883,
#         0.08335528], dtype=float32),
#  array([0.02178054, 0.03389497, 0.        , ..., 0.01610672, 0.0036931 ,
#         0.02517165], dtype=float32),
#  array([0.00893666, 0.05550081, 0.0182991 , ..., 0.01359649, 0.03201886,
#         0.02024407], dtype=float32),
#  array([0.01091238, 0.04633322, 0.00806556, ..., 0.00216071, 0.0187006 ,
#         0.0099537 ], dtype=float32),
#  array([0.01178102, 0.04088561, 0.01008993, ..., 0.00094427, 0.00493444,
#         0.04923021], dtype=float32),
#  array([0.00461249, 0.06143616, 0.0079189 , ..., 0.00699851, 0.0022021 ,
#         0.05746618], dtype=float32),
#  array([0.00690673, 0.06563711, 0.01937877, ..., 0.00587099, 0.01003861,
#         0.01787903], dtype=float32),
#  array([0.00251237, 0.00439561, 0.01273214, ..., 0.04361957, 0.00500529,
#         0.01775041], dtype=float32),
#  array([0.00446028, 0.00153988, 0.00573347, ..., 0.04387525, 0.00298799,
#         0.        ], dtype=float32),
#  array([0.01195025, 0.01089089, 0.        , ..., 0.05045503, 0.00179469,
#         0.05707814], dtype=float32),
#  array([3.7645688e-05, 1.2317439e-02, 3.1009197e-02, ..., 5.0496385e-02,
#         0.0000000e+00, 1.4770523e-02], dtype=float32),
#  array([0.00474286, 0.        , 0.00822614, ..., 0.06145446, 0.03403571,
#         0.        ], dtype=float32),
#  array([0.        , 0.0048618 , 0.00327004, ..., 0.0427443 , 0.00874126,
#         0.0150006 ], dtype=float32),
#  array([0.        , 0.03857613, 0.00742182, ..., 0.00609481, 0.0072258 ,
#         0.0054434 ], dtype=float32),
#  array([0.        , 0.03501412, 0.        , ..., 0.00588527, 0.        ,
#         0.01986322], dtype=float32),
#  array([0.        , 0.01252024, 0.        , ..., 0.00272171, 0.        ,
#         0.04520777], dtype=float32),
#  array([0.        , 0.03916309, 0.        , ..., 0.01001179, 0.01538827,
#         0.        ], dtype=float32),
#  array([0.        , 0.06041944, 0.        , ..., 0.00975444, 0.0003565 ,
#         0.01297283], dtype=float32),
#  array([0.        , 0.034321  , 0.        , ..., 0.01084099, 0.02596338,
#         0.        ], dtype=float32),
#  array([0.        , 0.        , 0.00176269, ..., 0.00227171, 0.01426104,
#         0.02556324], dtype=float32),
#  array([0.        , 0.        , 0.0164343 , ..., 0.01093595, 0.03464063,
#         0.0144334 ], dtype=float32),
#  array([0.00279811, 0.        , 0.01413887, ..., 0.0094615 , 0.02398393,
#         0.00896736], dtype=float32),
#  array([0.00613632, 0.        , 0.0270577 , ..., 0.00860255, 0.04321618,
#         0.01014413], dtype=float32),
#  array([0.000719  , 0.0010803 , 0.01715464, ..., 0.04074739, 0.0191695 ,
#         0.00049989], dtype=float32),
#  array([0.        , 0.        , 0.01689767, ..., 0.02361262, 0.00978741,
#         0.        ], dtype=float32),
#  array([0.00761946, 0.        , 0.03796143, ..., 0.05012301, 0.01822309,
#         0.0241614 ], dtype=float32),
#  array([0.00757225, 0.00062171, 0.05680681, ..., 0.02603665, 0.02708427,
#         0.        ], dtype=float32),
#  array([0.        , 0.        , 0.0266682 , ..., 0.00340419, 0.04409778,
#         0.00298401], dtype=float32),
#  array([0.00713296, 0.00626263, 0.02239112, ..., 0.02739011, 0.0360404 ,
#         0.01629396], dtype=float32),
#  array([0.00470848, 0.        , 0.        , ..., 0.037503  , 0.02216669,
#         0.01377992], dtype=float32),
#  array([0.        , 0.        , 0.00715377, ..., 0.02082138, 0.02194991,
#         0.00458745], dtype=float32),
#  array([0.00225943, 0.04567292, 0.        , ..., 0.        , 0.00018424,
#         0.03847498], dtype=float32),
#  array([0.00593824, 0.0109605 , 0.00209758, ..., 0.        , 0.        ,
#         0.01414276], dtype=float32),
#  array([0.        , 0.00993446, 0.        , ..., 0.        , 0.        ,
#         0.01540245], dtype=float32),
#  array([0.        , 0.05836721, 0.        , ..., 0.        , 0.00396768,
#         0.02227981], dtype=float32),
#  array([0.00517847, 0.0499885 , 0.        , ..., 0.        , 0.00662788,
#         0.01836565], dtype=float32),
#  array([0.00024285, 0.04344215, 0.01619246, ..., 0.        , 0.00297524,
#         0.01641183], dtype=float32),
#  array([0.0028551 , 0.06058443, 0.00578205, ..., 0.00657361, 0.00426191,
#         0.00890428], dtype=float32),
#  array([0.00997616, 0.0569316 , 0.00642626, ..., 0.00012325, 0.00879644,
#         0.02051684], dtype=float32),
#  array([0.0077823 , 0.04632137, 0.00143254, ..., 0.        , 0.02288246,
#         0.00453819], dtype=float32),
#  array([0.0012108 , 0.03610675, 0.00122025, ..., 0.00035847, 0.0241197 ,
#         0.02964516], dtype=float32),
#  array([0.00070577, 0.03535899, 0.        , ..., 0.00748921, 0.00550337,
#         0.0186444 ], dtype=float32),
#  array([0.00336977, 0.0268809 , 0.00773614, ..., 0.00606333, 0.00710111,
#         0.01486411], dtype=float32),
#  array([0.        , 0.04429273, 0.00095346, ..., 0.00351086, 0.01791663,
#         0.10451628], dtype=float32),
#  array([0.00034879, 0.02201461, 0.00443749, ..., 0.00496897, 0.0118157 ,
#         0.11778209], dtype=float32),
#  array([0.00205434, 0.04509257, 0.        , ..., 0.        , 0.03031885,
#         0.08294623], dtype=float32),
#  array([0.0052322 , 0.04028837, 0.        , ..., 0.00378349, 0.01350241,
#         0.09989101], dtype=float32),
#  array([0.        , 0.04239023, 0.        , ..., 0.        , 0.01495201,
#         0.102603  ], dtype=float32),
#  array([0.00164329, 0.05096797, 0.00195341, ..., 0.01237919, 0.01510626,
#         0.11522723], dtype=float32),
#  array([0.0000000e+00, 9.2756320e-03, 2.5508830e-02, ..., 7.4096274e-04,
#         7.5534172e-03, 8.4242449e-05], dtype=float32),
#  array([0.00121269, 0.0253298 , 0.02199998, ..., 0.03099765, 0.02204594,
#         0.        ], dtype=float32),
#  array([0.        , 0.0172518 , 0.02785665, ..., 0.00346545, 0.03069519,
#         0.00335978], dtype=float32),
#  array([0.        , 0.00839916, 0.02155911, ..., 0.00929028, 0.02100596,
#         0.00597931], dtype=float32),
#  array([0.        , 0.01074778, 0.03203443, ..., 0.        , 0.01271399,
#         0.00203297], dtype=float32),
#  array([0.00967173, 0.00404125, 0.00901646, ..., 0.00087306, 0.02878173,
#         0.01370514], dtype=float32),
#  array([0.00392627, 0.00209363, 0.00563714, ..., 0.02666203, 0.01822083,
#         0.0063015 ], dtype=float32),
#  array([0.        , 0.        , 0.01297518, ..., 0.04029014, 0.01092832,
#         0.01851711], dtype=float32),
#  array([0.        , 0.01301179, 0.01337506, ..., 0.        , 0.03642399,
#         0.00203761], dtype=float32),
#  array([0.        , 0.0062588 , 0.01658436, ..., 0.00097784, 0.00536959,
#         0.00685963], dtype=float32),
#  array([0.        , 0.02019311, 0.01963983, ..., 0.        , 0.00804656,
#         0.01333743], dtype=float32),
#  array([0.02921469, 0.00340571, 0.0079393 , ..., 0.00385808, 0.04172437,
#         0.        ], dtype=float32),
#  array([0.01866702, 0.01140623, 0.0264222 , ..., 0.00450582, 0.02177218,
#         0.        ], dtype=float32),
#  array([2.4940867e-02, 6.1443718e-03, 1.7248981e-02, ..., 2.1105828e-03,
#         3.2450240e-02, 7.7416189e-05], dtype=float32),
#  array([0.03013992, 0.00504832, 0.01909916, ..., 0.00132035, 0.03595861,
#         0.00513995], dtype=float32),
#  array([0.00439482, 0.00420937, 0.00167341, ..., 0.00933892, 0.03914933,
#         0.01113839], dtype=float32),
#  array([0.02043102, 0.00278415, 0.        , ..., 0.03759229, 0.03893461,
#         0.        ], dtype=float32),
#  array([0.00743835, 0.00509998, 0.00222768, ..., 0.01540915, 0.02257976,
#         0.00616931], dtype=float32),
#  array([0.        , 0.00888114, 0.00683672, ..., 0.02378149, 0.03448363,
#         0.02260418], dtype=float32),
#  array([0.        , 0.00371119, 0.01022693, ..., 0.01939233, 0.06991868,
#         0.00776057], dtype=float32),
#  array([0.        , 0.00850459, 0.00030068, ..., 0.04543388, 0.0338713 ,
#         0.        ], dtype=float32),
#  array([0.        , 0.00912544, 0.00562949, ..., 0.05074315, 0.03487586,
#         0.        ], dtype=float32),
#  array([0.        , 0.00888353, 0.        , ..., 0.04030821, 0.0166148 ,
#         0.00364723], dtype=float32),
#  array([0.00153189, 0.04405355, 0.01378307, ..., 0.00852905, 0.01540546,
#         0.03149022], dtype=float32),
#  array([0.00697383, 0.03332577, 0.01538308, ..., 0.00074721, 0.01114486,
#         0.01603237], dtype=float32),
#  array([0.01295841, 0.04787729, 0.00273305, ..., 0.00862597, 0.04440993,
#         0.00908296], dtype=float32),
#  array([0.00317115, 0.03614558, 0.00333044, ..., 0.01189595, 0.00051223,
#         0.02305776], dtype=float32),
#  array([0.01024045, 0.03838965, 0.00170992, ..., 0.00642472, 0.01782295,
#         0.01918664], dtype=float32),
#  array([0.        , 0.01108482, 0.00126368, ..., 0.0114845 , 0.00298448,
#         0.        ], dtype=float32),
#  array([0.        , 0.02342011, 0.0008086 , ..., 0.01422054, 0.        ,
#         0.01273908], dtype=float32),
#  array([0.        , 0.01667226, 0.        , ..., 0.00369209, 0.00467723,
#         0.        ], dtype=float32),
#  array([0.        , 0.03936407, 0.        , ..., 0.00400229, 0.01654693,
#         0.        ], dtype=float32),
#  array([0.        , 0.03648553, 0.        , ..., 0.01443599, 0.01827068,
#         0.        ], dtype=float32),
#  array([0.        , 0.00190062, 0.        , ..., 0.01974064, 0.04770508,
#         0.        ], dtype=float32),
#  array([0.        , 0.03635445, 0.        , ..., 0.00919777, 0.01983204,
#         0.        ], dtype=float32),
#  array([0.        , 0.0067173 , 0.        , ..., 0.01086977, 0.        ,
#         0.00718063], dtype=float32),
#  array([0.        , 0.00377195, 0.01565604, ..., 0.0062008 , 0.01223677,
#         0.        ], dtype=float32),
#  array([0.        , 0.00218842, 0.01607503, ..., 0.00105249, 0.00189795,
#         0.01158822], dtype=float32),
#  array([0.        , 0.        , 0.        , ..., 0.00741095, 0.        ,
#         0.00366237], dtype=float32),
#  array([0.0036971 , 0.        , 0.00341482, ..., 0.00207179, 0.0081462 ,
#         0.00933255], dtype=float32),
#  array([0.        , 0.00663925, 0.01245846, ..., 0.        , 0.00216519,
#         0.00464061], dtype=float32),
#  array([0.        , 0.04840328, 0.00090641, ..., 0.01780855, 0.01081452,
#         0.07834079], dtype=float32),
#  array([0.        , 0.06471802, 0.        , ..., 0.01989926, 0.01604266,
#         0.04725397], dtype=float32),
#  array([0.00683886, 0.01807566, 0.        , ..., 0.02603459, 0.02555274,
#         0.04460788], dtype=float32),
#  array([0.0012283 , 0.0163836 , 0.        , ..., 0.02895999, 0.01226988,
#         0.03330551], dtype=float32),
#  array([0.        , 0.01960063, 0.        , ..., 0.02651884, 0.01697029,
#         0.03928989], dtype=float32),
#  array([0.01112065, 0.03806216, 0.00604147, ..., 0.        , 0.00588759,
#         0.05886135], dtype=float32),
#  array([0.00264512, 0.        , 0.01382887, ..., 0.01154109, 0.01696116,
#         0.00140025], dtype=float32),
#  array([0.        , 0.00070299, 0.00430523, ..., 0.01757772, 0.02487969,
#         0.01253032], dtype=float32),
#  array([0.00059847, 0.00040678, 0.00985324, ..., 0.01240121, 0.0134021 ,
#         0.        ], dtype=float32),
#  array([0.00792276, 0.00201893, 0.00668071, ..., 0.0075146 , 0.00190055,
#         0.00021559], dtype=float32),
#  array([0.01291243, 0.00075567, 0.02414277, ..., 0.01580498, 0.01978143,
#         0.00613381], dtype=float32),
#  array([0.00663118, 0.        , 0.01012393, ..., 0.01200578, 0.01834673,
#         0.        ], dtype=float32),
#  array([0.00446022, 0.        , 0.00097242, ..., 0.01209109, 0.01309823,
#         0.        ], dtype=float32),
#  array([0.        , 0.01367856, 0.00276294, ..., 0.00030448, 0.04194375,
#         0.        ], dtype=float32),
#  array([0.00227558, 0.01684007, 0.        , ..., 0.03752279, 0.07346623,
#         0.0041302 ], dtype=float32),
#  array([0.00165718, 0.03023213, 0.        , ..., 0.02854326, 0.06687204,
#         0.        ], dtype=float32),
#  array([0.00710174, 0.02771626, 0.00782842, ..., 0.00531377, 0.00341483,
#         0.        ], dtype=float32),
#  array([0.        , 0.01860603, 0.0047095 , ..., 0.        , 0.04506187,
#         0.        ], dtype=float32),
#  array([0.00586001, 0.00286328, 0.00264084, ..., 0.00808235, 0.04429036,
#         0.00193276], dtype=float32),
#  array([0.01182022, 0.03373075, 0.        , ..., 0.00343605, 0.05692094,
#         0.02857033], dtype=float32),
#  array([0.        , 0.06782755, 0.007944  , ..., 0.03403608, 0.04072975,
#         0.01369438], dtype=float32),
#  array([0.00152884, 0.06420681, 0.00103604, ..., 0.        , 0.02995075,
#         0.00670347], dtype=float32),
#  array([0.        , 0.02711733, 0.00530011, ..., 0.03504436, 0.03208585,
#         0.01775287], dtype=float32),
#  array([0.        , 0.06764927, 0.0039007 , ..., 0.00312546, 0.03459866,
#         0.02523226], dtype=float32),
#  array([0.00426262, 0.04444099, 0.        , ..., 0.        , 0.04026058,
#         0.        ], dtype=float32),
#  array([0.00268258, 0.04919416, 0.        , ..., 0.00584373, 0.02682703,
#         0.        ], dtype=float32),
#  array([0.        , 0.00501287, 0.00605532, ..., 0.01519972, 0.        ,
#         0.00098817], dtype=float32),
#  array([0.        , 0.00692741, 0.01079474, ..., 0.0074705 , 0.        ,
#         0.00015475], dtype=float32),
#  array([0.00853275, 0.00869713, 0.        , ..., 0.00490447, 0.        ,
#         0.02383884], dtype=float32),
#  array([0.00052916, 0.01560555, 0.00518952, ..., 0.00213446, 0.        ,
#         0.00178328], dtype=float32),
#  array([0.        , 0.00509087, 0.00315963, ..., 0.        , 0.        ,
#         0.00617413], dtype=float32),
#  array([0.00040212, 0.01262242, 0.01637002, ..., 0.00106116, 0.00080879,
#         0.        ], dtype=float32),
#  array([0.        , 0.01268198, 0.        , ..., 0.00291491, 0.        ,
#         0.01832354], dtype=float32),
#  array([0.00255945, 0.01011514, 0.0008057 , ..., 0.00716055, 0.05803419,
#         0.06410667], dtype=float32),
#  array([0.0006163 , 0.01807529, 0.        , ..., 0.0068048 , 0.02894502,
#         0.04427239], dtype=float32),
#  array([0.00521914, 0.00525019, 0.00890061, ..., 0.00676895, 0.01096173,
#         0.05643767], dtype=float32),
#  array([0.0039669 , 0.03222374, 0.00619146, ..., 0.00856212, 0.0290999 ,
#         0.0453326 ], dtype=float32),
#  array([0.0145704 , 0.0386253 , 0.00384365, ..., 0.00512257, 0.01150491,
#         0.06034377], dtype=float32),
#  array([0.00953326, 0.04273708, 0.01430385, ..., 0.01975319, 0.00632016,
#         0.01801608], dtype=float32),
#  array([0.01350052, 0.02400146, 0.        , ..., 0.00917622, 0.01135417,
#         0.03554636], dtype=float32),
#  array([0.00236299, 0.02952055, 0.00180619, ..., 0.01125148, 0.01486232,
#         0.03977897], dtype=float32),
#  array([0.00361919, 0.03605106, 0.00065217, ..., 0.01552999, 0.        ,
#         0.03621038], dtype=float32),
#  array([0.00361919, 0.03605106, 0.00065217, ..., 0.01552999, 0.        ,
#         0.03621038], dtype=float32),
#  array([0.00226574, 0.        , 0.        , ..., 0.01431147, 0.01102137,
#         0.0073517 ], dtype=float32),
#  array([0.        , 0.01210885, 0.00428897, ..., 0.00451851, 0.03875404,
#         0.01132419], dtype=float32),
#  array([0.00687655, 0.00379958, 0.02351576, ..., 0.01345327, 0.01298741,
#         0.01740136], dtype=float32),
#  array([0.00917523, 0.00628782, 0.00317382, ..., 0.01113384, 0.02989604,
#         0.00194553], dtype=float32),
#  array([1.7194968e-03, 0.0000000e+00, 4.2229970e-03, ..., 1.1445489e-02,
#         9.7689217e-06, 4.1199657e-03], dtype=float32),
#  array([0.00256517, 0.0224744 , 0.00093468, ..., 0.00267318, 0.02311454,
#         0.02055896], dtype=float32),
#  array([0.        , 0.        , 0.02538612, ..., 0.02507817, 0.01969754,
#         0.        ], dtype=float32),
#  array([0.00529929, 0.0276104 , 0.00539972, ..., 0.00126746, 0.02237739,
#         0.00500305], dtype=float32),
#  array([0.01068562, 0.02334656, 0.01147304, ..., 0.00236327, 0.01932811,
#         0.02570377], dtype=float32),
#  array([0.00171679, 0.02595278, 0.00045383, ..., 0.00263614, 0.00591631,
#         0.02076229], dtype=float32),
#  array([0.00909183, 0.02370739, 0.00085614, ..., 0.00188226, 0.01672732,
#         0.03977827], dtype=float32),
#  array([0.00422311, 0.02918062, 0.00272861, ..., 0.        , 0.01218203,
#         0.00953878], dtype=float32),
#  array([0.0105523 , 0.03027589, 0.00419016, ..., 0.00249754, 0.01362137,
#         0.02096707], dtype=float32),
#  array([0.00784837, 0.03212873, 0.0119364 , ..., 0.00081512, 0.02700221,
#         0.00971298], dtype=float32),
#  array([0.00130716, 0.02985211, 0.00180192, ..., 0.02719126, 0.03816979,
#         0.04438695], dtype=float32),
#  array([0.02407274, 0.02253558, 0.00460298, ..., 0.        , 0.0347009 ,
#         0.000492  ], dtype=float32),
#  array([0.01487891, 0.00442007, 0.00285156, ..., 0.00208654, 0.00821789,
#         0.02729699], dtype=float32),
#  array([0.0089396 , 0.03846647, 0.00132304, ..., 0.0179051 , 0.04375797,
#         0.04259824], dtype=float32),
#  array([0.02481847, 0.01768547, 0.00079265, ..., 0.0311775 , 0.00480939,
#         0.0884204 ], dtype=float32),
#  array([0.01024059, 0.02579726, 0.        , ..., 0.02545104, 0.        ,
#         0.00235599], dtype=float32),
#  array([0.005975  , 0.00966141, 0.01088841, ..., 0.01420137, 0.02072576,
#         0.01292433], dtype=float32),
#  array([0.00186466, 0.00359083, 0.        , ..., 0.01544207, 0.00736355,
#         0.07838277], dtype=float32),
#  array([0.0115553 , 0.02717006, 0.00744528, ..., 0.00347678, 0.01225108,
#         0.05335778], dtype=float32),
#  array([0.00772257, 0.02077335, 0.00648978, ..., 0.0060228 , 0.02968385,
#         0.        ], dtype=float32),
#  array([0.00380993, 0.0113179 , 0.00722851, ..., 0.01623716, 0.01546221,
#         0.03867725], dtype=float32),
#  array([0.00955341, 0.01323301, 0.00879196, ..., 0.00657195, 0.03295382,
#         0.01366498], dtype=float32),
#  array([0.02312101, 0.02297004, 0.01506049, ..., 0.01504356, 0.0077483 ,
#         0.02612355], dtype=float32),
#  array([0.01443252, 0.0135023 , 0.02436407, ..., 0.02039324, 0.        ,
#         0.        ], dtype=float32),
#  array([0.02015451, 0.02623424, 0.01037102, ..., 0.02228263, 0.0060296 ,
#         0.00961504], dtype=float32),
#  array([0.00756586, 0.00675341, 0.        , ..., 0.02306885, 0.00200792,
#         0.0505519 ], dtype=float32),
#  array([0.03903656, 0.03142114, 0.        , ..., 0.03315518, 0.01041403,
#         0.02166122], dtype=float32),
#  array([4.2866301e-03, 2.3334436e-02, 0.0000000e+00, ..., 3.0728808e-02,
#         9.1428396e-05, 1.0232170e-02], dtype=float32),
#  array([0.02520244, 0.01282381, 0.00717398, ..., 0.01231844, 0.02163493,
#         0.02424544], dtype=float32),
#  array([0.04339276, 0.00058981, 0.        , ..., 0.03248294, 0.01132197,
#         0.0416505 ], dtype=float32),
#  array([0.01847123, 0.02482886, 0.01865365, ..., 0.0206139 , 0.0384023 ,
#         0.01272325], dtype=float32),
#  array([0.04130616, 0.04390503, 0.01741663, ..., 0.01794028, 0.02191862,
#         0.02826646], dtype=float32),
#  array([0.00896093, 0.04660975, 0.00362976, ..., 0.01218223, 0.01921997,
#         0.0308153 ], dtype=float32),
#  array([0.01087714, 0.00721492, 0.00699779, ..., 0.00616774, 0.0183939 ,
#         0.03502148], dtype=float32),
#  array([0.02106934, 0.02203828, 0.        , ..., 0.02772213, 0.        ,
#         0.00537628], dtype=float32),
#  array([0.00699555, 0.01079859, 0.005012  , ..., 0.00647428, 0.        ,
#         0.01391692], dtype=float32),
#  array([0.00813913, 0.01492396, 0.00151476, ..., 0.00775315, 0.04575271,
#         0.01708013], dtype=float32),
#  array([0.01453395, 0.0143326 , 0.        , ..., 0.00317997, 0.0090835 ,
#         0.00986609], dtype=float32),
#  array([0.02199678, 0.027018  , 0.01517623, ..., 0.03047218, 0.        ,
#         0.01331592], dtype=float32),
#  array([0.01303083, 0.01158271, 0.00472473, ..., 0.01361835, 0.        ,
#         0.03682042], dtype=float32),
#  array([0.01370383, 0.02705326, 0.00719099, ..., 0.00755329, 0.04185119,
#         0.01805369], dtype=float32),
#  array([0.01092102, 0.03210619, 0.        , ..., 0.02123912, 0.00492245,
#         0.04705808], dtype=float32),
#  array([0.01056468, 0.00551075, 0.00704771, ..., 0.02725297, 0.01344024,
#         0.00362641], dtype=float32),
#  array([0.01484448, 0.02114357, 0.00240252, ..., 0.02088984, 0.00269941,
#         0.06298803], dtype=float32),
#  array([0.01180766, 0.06361894, 0.        , ..., 0.0084762 , 0.01107224,
#         0.00167693], dtype=float32),
#  array([0.01484603, 0.01094592, 0.01105307, ..., 0.00249844, 0.02359894,
#         0.00879413], dtype=float32),
#  array([0.004944  , 0.03687115, 0.01014304, ..., 0.00488433, 0.00185199,
#         0.04317477], dtype=float32),
#  array([0.03707937, 0.01964964, 0.01364556, ..., 0.03648577, 0.00995697,
#         0.00766897], dtype=float32),
#  array([0.00288824, 0.02028625, 0.00206981, ..., 0.01423617, 0.0137082 ,
#         0.04023999], dtype=float32),
#  array([0.00321913, 0.03592154, 0.01675812, ..., 0.01503941, 0.01343849,
#         0.09683756], dtype=float32),
#  array([0.00762622, 0.00953893, 0.00181717, ..., 0.00418356, 0.01256711,
#         0.04912109], dtype=float32),
#  array([0.0046211 , 0.02742402, 0.        , ..., 0.00921837, 0.00845151,
#         0.00587292], dtype=float32),
#  array([0.00622117, 0.02290115, 0.02023598, ..., 0.01052678, 0.00320914,
#         0.06010421], dtype=float32),
#  array([0.01393197, 0.01633149, 0.02007793, ..., 0.01800245, 0.02555633,
#         0.03715511], dtype=float32),
#  array([0.0294712 , 0.07578205, 0.00770982, ..., 0.01922082, 0.00972501,
#         0.04829973], dtype=float32),
#  array([0.01804639, 0.00772796, 0.        , ..., 0.00715692, 0.01062575,
#         0.02375928], dtype=float32),
#  array([0.0053364 , 0.0252406 , 0.        , ..., 0.00114786, 0.00553054,
#         0.07165474], dtype=float32),
#  array([0.04083504, 0.01408984, 0.00308605, ..., 0.00427645, 0.00519195,
#         0.00808199], dtype=float32),
#  array([0.04273464, 0.02274047, 0.00464616, ..., 0.02634688, 0.01170015,
#         0.03531111], dtype=float32),
#  array([0.00904331, 0.02914924, 0.01472972, ..., 0.00360996, 0.00454747,
#         0.05073196], dtype=float32),
#  array([0.00630254, 0.03679997, 0.01116963, ..., 0.01336919, 0.0174165 ,
#         0.046289  ], dtype=float32),
#  array([0.00363029, 0.01378913, 0.02514504, ..., 0.03426704, 0.03988589,
#         0.06437854], dtype=float32),
#  array([0.04093377, 0.03983929, 0.01947914, ..., 0.0130882 , 0.00185423,
#         0.04837764], dtype=float32),
#  array([0.01379009, 0.01358928, 0.00795279, ..., 0.00057925, 0.05007203,
#         0.00999154], dtype=float32),
#  array([0.03562581, 0.0171593 , 0.00809616, ..., 0.00726399, 0.00924257,
#         0.03627738], dtype=float32),
#  array([0.01315047, 0.03720182, 0.02523863, ..., 0.00825279, 0.01993436,
#         0.01210915], dtype=float32),
#  array([0.0081984 , 0.03700776, 0.        , ..., 0.03139025, 0.02446753,
#         0.01995709], dtype=float32),
#  array([0.0093785 , 0.04954222, 0.00583174, ..., 0.01682956, 0.00995557,
#         0.02442245], dtype=float32),
#  array([0.01284375, 0.01870485, 0.0041188 , ..., 0.01330828, 0.02058816,
#         0.02461059], dtype=float32),
#  array([0.00787763, 0.02375282, 0.00948444, ..., 0.01256796, 0.02705509,
#         0.01654263], dtype=float32),
#  array([0.00897276, 0.02975464, 0.00733153, ..., 0.01344627, 0.02684871,
#         0.02033677], dtype=float32),
#  array([0.00912529, 0.03548426, 0.00579834, ..., 0.02221026, 0.00615389,
#         0.02110689], dtype=float32),
#  array([0.0243809 , 0.01171782, 0.00908169, ..., 0.02559574, 0.00181898,
#         0.        ], dtype=float32),
#  array([0.01433491, 0.01698054, 0.00499273, ..., 0.03346772, 0.01120963,
#         0.00998477], dtype=float32),
#  array([0.00692573, 0.01706385, 0.        , ..., 0.01032108, 0.02170832,
#         0.0594791 ], dtype=float32),
#  array([0.00569239, 0.01828015, 0.00607724, ..., 0.01666525, 0.00445719,
#         0.02268925], dtype=float32),
#  array([0.00738005, 0.02298377, 0.00077771, ..., 0.01640849, 0.02884481,
#         0.01390001], dtype=float32),
#  array([0.02824065, 0.02512581, 0.00627972, ..., 0.        , 0.02475482,
#         0.02976015], dtype=float32),
#  array([0.02477348, 0.0320138 , 0.00702011, ..., 0.0145014 , 0.00817384,
#         0.02384488], dtype=float32),
#  array([0.00554926, 0.0196789 , 0.00868115, ..., 0.01409117, 0.02536559,
#         0.00600184], dtype=float32),
#  array([0.0185626 , 0.00295523, 0.00495466, ..., 0.01301424, 0.00514365,
#         0.03863923], dtype=float32),
#  array([0.0096468 , 0.00648778, 0.02311122, ..., 0.01934811, 0.00984925,
#         0.07097723], dtype=float32),
#  array([0.00418191, 0.02249467, 0.        , ..., 0.05304107, 0.00380994,
#         0.01123224], dtype=float32),
#  array([0.        , 0.05501546, 0.00403791, ..., 0.01825186, 0.        ,
#         0.00998921], dtype=float32),
#  array([0.02161558, 0.01965851, 0.01195606, ..., 0.00750146, 0.01230703,
#         0.01325551], dtype=float32),
#  array([0.01052625, 0.0303614 , 0.01593264, ..., 0.0030772 , 0.03252279,
#         0.04636129], dtype=float32),
#  array([0.0102019 , 0.02822798, 0.        , ..., 0.02984681, 0.        ,
#         0.00541527], dtype=float32),
#  array([0.01241702, 0.03866056, 0.00906092, ..., 0.01576728, 0.00508356,
#         0.01902574], dtype=float32),
#  array([0.02284635, 0.03373016, 0.0041807 , ..., 0.01729738, 0.        ,
#         0.0156988 ], dtype=float32),
#  array([0.02219087, 0.01955654, 0.0039461 , ..., 0.0108422 , 0.00675245,
#         0.05461219], dtype=float32),
#  array([0.00289229, 0.02000991, 0.        , ..., 0.04015638, 0.00015224,
#         0.02996868], dtype=float32),
#  array([0.02467618, 0.03516653, 0.00351694, ..., 0.05605831, 0.00031384,
#         0.05878083], dtype=float32),
#  array([0.00916507, 0.01863647, 0.02055822, ..., 0.01045665, 0.00144783,
#         0.01147915], dtype=float32),
#  array([0.01239106, 0.02213154, 0.00075929, ..., 0.03558517, 0.        ,
#         0.0107515 ], dtype=float32),
#  array([0.02224518, 0.0296929 , 0.01176007, ..., 0.        , 0.0124144 ,
#         0.02887207], dtype=float32),
#  array([0.00181383, 0.02089026, 0.02412257, ..., 0.02931299, 0.00976381,
#         0.04743382], dtype=float32),
#  array([0.00542519, 0.004383  , 0.01420657, ..., 0.03605102, 0.00312744,
#         0.00620201], dtype=float32),
#  array([0.00381247, 0.0028016 , 0.00668951, ..., 0.04210364, 0.00386849,
#         0.03941185], dtype=float32),
#  array([0.00265223, 0.00758172, 0.00865991, ..., 0.01011337, 0.02125999,
#         0.02107967], dtype=float32),
#  array([0.00777363, 0.03277434, 0.01071725, ..., 0.01259127, 0.00606462,
#         0.03838803], dtype=float32),
#  array([0.01715809, 0.02366068, 0.        , ..., 0.01238453, 0.04651961,
#         0.09661163], dtype=float32),
#  array([0.01988124, 0.04254561, 0.01665201, ..., 0.01377554, 0.00432548,
#         0.00590632], dtype=float32),
#  array([0.01076692, 0.01015078, 0.00213927, ..., 0.01972475, 0.01915398,
#         0.02531749], dtype=float32),
#  array([4.3054190e-03, 1.6410250e-02, 1.2077922e-05, ..., 8.4827784e-03,
#         2.2395018e-02, 2.0480132e-02], dtype=float32),
#  array([0.0069861 , 0.0060667 , 0.00787652, ..., 0.02574704, 0.03829671,
#         0.05424599], dtype=float32)]

# %%
Image_features = pkl.dump(image_features, open('Images_features.pkl','wb'))

# %%
filenames = pkl.dump(filenames, open('filenames.pkl','wb'))

# %%
#Loading Pickle Files

# %%
Image_features = pkl.load(open('Images_features.pkl','rb'))

# %%
filenames = pkl.load(open('filenames.pkl','rb'))

# %%
np.array(Image_features).shape
# Out:
# (268, 2048)

# %%
#Finidng Simialar Images

# %%
neighbors = NearestNeighbors(n_neighbors=6, algorithm='brute', metric='euclidean')

# %%
neighbors.fit(Image_features)
# Out:
# NearestNeighbors(algorithm='brute', metric='euclidean', n_neighbors=6)

# %%
input_image = extract_features_from_images('8852.jpg',model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step

# %%
distance,indices = neighbors.kneighbors([input_image])

# %%
indices[0]
# Out:
# array([167, 171, 168, 169, 170, 166], dtype=int64)

# %%
from IPython.display import Image

# %%
Image('8852.jpg')

# %%
Image(filenames[indices[0][1]])

# %%
Image(filenames[indices[0][2]])

# %%
Image(filenames[indices[0][3]])

# %%
Image(filenames[indices[0][4]])

# %%
Image(filenames[indices[0][5]])
